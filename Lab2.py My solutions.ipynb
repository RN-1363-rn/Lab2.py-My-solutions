# %% [markdown]
# # Lab 2 - My solutions
# **Graphical representation of functions**<br>
# Software 1 - Mathematics<br>
# Information and Communication Technology<br>
# Metropolia University of Applied Sciences

# %% [markdown]
# ## Setup

# %%
name = "Reihaneh" # Write your name between parenthesis
student_id = 2600562 # Change your student ID here
date_returned = "11.03.2026" # Write the date returned between the parenthesis

# %%
from IPython.display import Markdown, display
import numpy as np
import matplotlib.pyplot as plt
import labx as mx # Remenber to donwload labx.pyc from the course website

# %% [markdown]
# ---
# ## My solution for problem 1

# %%
from IPython.display import Markdown, display
import numpy as np
import matplotlib.pyplot as plt
import labx as mx
student_id = 2600562
x = np.linspace(-10, 10, 2000)
y = mx.lab_2_problem_1(x, student_id)
plt.figure()
plt.plot(x, y)
plt.axhline(0)
plt.title("Overview: All roots")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()

# %%
plt.figure()
plt.plot(x, y)
plt.axhline(0)

plt.xlim(-2.2, -1.8)
plt.ylim(-5, 5)

plt.title("Root 1 (zoom)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)

plt.show()

# %%
plt.figure()
plt.plot(x, y)
plt.axhline(0)
plt.xlim(-2.5, -1.3)
plt.ylim(-5, 5)
plt.title("Root 2 (zoom)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()

# %%
plt.figure()
plt.plot(x, y)
plt.axhline(0)
plt.xlim(1.5, 2.8)
plt.ylim(-5, 5)
plt.title("Root 3 (zoom)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()

# %%
plt.figure()
plt.plot(x, y)
plt.axhline(0)

plt.xlim(2.5, 3.5)
plt.ylim(-5, 5)

plt.title("Root 4 (zoom)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)

plt.show()

# %% [markdown]
# ---
#
# ## Problem 2

# %%
# Run the code below to see your problem text
txt = mx.lab_2_problem_2(student_id)
display(Markdown(txt))
# Out:
# In this problem your task is to plot two functions and
# graphically find the intersection points of the two functions.
#
# The first functions is $$ f(x) = \sqrt{4.5x} $$ and
# the second function is $$ g(x) = (x - 5.31)^2 $$.
#
# First, plot the two functions in the same graph. Make this first plot to show the functions in the
# larger range of $x$ values, say $x \in [0, 10]$.
#
# Then plot the two functions in another graph, but now show the functions in the smaller range of
# $x$ values. In this second plot, make sure to show the intersection points of the two functions.
# What are their values? Find the values *graphically*.
#
# Finally, remember to decorate the plots with title, axis labels, and a legend. Add also grid
# lines to the plots to make them easier to read.

# %%
x = np.linspace(0, 10, 500)

f = np.sqrt(3.4 * x)
g = (x - 4.25)**2

plt.figure()
plt.plot(x, f, label='f(x)')
plt.plot(x, g, label='g(x)')
plt.title("Overview of f(x) and g(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure()
plt.plot(x, f, label='f(x)')
plt.plot(x, g, label='g(x)')
plt.xlim(0, 3)
plt.ylim(0, 5)
plt.title("Intersection 1 (zoomed)")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure()
plt.plot(x, f, label='f(x)')
plt.plot(x, g, label='g(x)')
plt.xlim(4, 7)
plt.ylim(0, 5)
plt.title("Intersection 2 (zoomed)")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### My solution

# %%
# Your code starts here
